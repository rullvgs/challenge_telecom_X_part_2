# %% [markdown]
# #📌 Extracción

# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/ingridcristh/challenge2-data-science-LATAM/5adf5f2f87a72bd8b2e854db16e2f2f7c499081a/TelecomX_Data.json'
datos = pd.read_json(url)
datos.sample(10)
# Out:
#       customerID Churn                                           customer  \
# 5998  8199-ZLLSA   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 353   0512-FLFDW    No  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# 4172  5712-VBOXD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 4622  6339-RZCBJ    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 6687  9206-GVPEQ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7158  9840-GSRFX        {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 6158  8430-TWCBX    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 4264  5862-BRIXZ    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 114   0195-IESCP   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 581   0829-XXPLX    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
#
#                                                   phone  \
# 5998    {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 353     {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 4172     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4622     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 6687  {'PhoneService': 'No', 'MultipleLines': 'No ph...
# 7158    {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 6158     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4264  {'PhoneService': 'No', 'MultipleLines': 'No ph...
# 114     {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 581      {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                                internet  \
# 5998  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 353   {'InternetService': 'Fiber optic', 'OnlineSecu...
# 4172  {'InternetService': 'No', 'OnlineSecurity': 'N...
# 4622  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 6687  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7158  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 6158  {'InternetService': 'No', 'OnlineSecurity': 'N...
# 4264  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 114   {'InternetService': 'Fiber optic', 'OnlineSecu...
# 581   {'InternetService': 'Fiber optic', 'OnlineSecu...
#
#                                                 account
# 5998  {'Contract': 'One year', 'PaperlessBilling': '...
# 353   {'Contract': 'One year', 'PaperlessBilling': '...
# 4172  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 4622  {'Contract': 'Two year', 'PaperlessBilling': '...
# 6687  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 7158  {'Contract': 'One year', 'PaperlessBilling': '...
# 6158  {'Contract': 'One year', 'PaperlessBilling': '...
# 4264  {'Contract': 'Two year', 'PaperlessBilling': '...
# 114   {'Contract': 'Month-to-month', 'PaperlessBilli...
# 581   {'Contract': 'Month-to-month', 'PaperlessBilli...

# %% [markdown]
# #🔧 Transformación

# %% [markdown]
# #📊 Carga y análisis

# %% [markdown]
# #📄Informe final
